# %%
import numpy as np

# %%
from pyiron_atomistics import Project

# %%
from pyiron_atomistics.atomistics.master.phonopy import phonopy_to_atoms, atoms_to_phonopy

# %%
from phono3py import Phono3py

# %%
from phonopy.structure.atoms import PhonopyAtoms

# %%
scaled_positions = [
    [0.8750000000000000,  0.8750000000000000,  0.8750000000000000],
    [0.8750000000000000,  0.3750000000000000,  0.3750000000000000],
    [0.3750000000000000,  0.8750000000000000,  0.3750000000000000],
    [0.3750000000000000,  0.3750000000000000,  0.8750000000000000],
    [0.1250000000000000,  0.1250000000000000,  0.1250000000000000],
    [0.1250000000000000,  0.6250000000000000,  0.6250000000000000],
    [0.6250000000000000,  0.1250000000000000,  0.6250000000000000],
    [0.6250000000000000,  0.6250000000000000,  0.1250000000000000],
]

# %%
cell = [
    [5.4662628900000003,    0.0000000000000000,    0.0000000000000000],
    [0.0000000000000000,    5.4662628900000003,    0.0000000000000000],
    [0.0000000000000000,    0.0000000000000000,    5.4662628900000003],
]

# %%
symbols=["Si"] * 8

# %%
atoms = PhonopyAtoms(
    symbols=symbols,
    scaled_positions=scaled_positions,
    cell=cell,
)

# %%
pr = Project("calc")

# %%
pr.remove_jobs(silently=True, recursive=True)
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
job_mini = pr.create.job.Lammps("job_mini")

# %%
job_mini.structure = phonopy_to_atoms(atoms)

# %%
job_mini.potential = '1994--Tersoff-J--Si-C--LAMMPS--ipr1'

# %%
job_mini.calc_minimize(pressure=0)

# %%
job_mini.run()
# Out:
# The job job_mini was saved and received the ID: 1

# %%
atoms = atoms_to_phonopy(job_mini.get_final_structure())
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: pyiron_atomistics.lammps.base.get_final_structure is deprecated: use get_structure() instead.
#   """Entry point for launching an IPython kernel.

# %%
phono = Phono3py(
    unitcell=atoms,
    supercell_matrix=[2,2,2],
    primitive_matrix=[[0, 1/2, 1/2], [1/2, 0, 1/2], [1/2, 1/2, 0]],
    phonon_supercell_matrix=[4,4,4],
    # masses=None,
    # band_indices=None,
    # sigmas=None,
    # sigma_cutoff=None,
    # cutoff_frequency=1e-4,
    # frequency_factor_to_THz=VaspToTHz,
    # is_symmetry=True,
    # is_mesh_symmetry=True,
    # use_grg=False,
    # symmetrize_fc3q=None,
    # store_dense_gp_map=True,
    # store_dense_svecs=True,
    # symprec=1e-5,
    # calculator=None,
    # log_level=0,
    # lapack_zheev_uplo=None,
)

# %%
phono.mesh_numbers = [11,11,11]

# %%
phono.generate_displacements(cutoff_pair_distance=3.0)
phono.generate_fc2_displacements()

# %%
phono.dataset
# Out:
# {'natom': 64,
#  'cutoff_distance': 3.0,
#  'first_atoms': [{'number': 0,
#    'direction': [1, 0, 0],
#    'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#    'id': 1,
#    'second_atoms': [{'id': 2,
#      'number': 0,
#      'direction': [1, 1, 0],
#      'displacement': array([2.12132034e-02, 2.12132034e-02, 2.59786817e-18]),
#      'pair_distance': 0.0,
#      'included': True},
#     {'id': 3,
#      'number': 0,
#      'direction': [-1, -1, 0],
#      'displacement': array([-2.12132034e-02, -2.12132034e-02, -2.59786817e-18]),
#      'pair_distance': 0.0,
#      'included': True},
#     {'id': 4,
#      'number': 1,
#      'direction': [1, 1, 0],
#      'displacement': array([2.12132034e-02, 2.12132034e-02, 2.59786817e-18]),
#      'pair_distance': 5.432005264118769,
#      'included': False},
#     {'id': 5,
#      'number': 1,
#      'direction': [-1, -1, 0],
#      'displacement': array([-2.12132034e-02, -2.12132034e-02, -2.59786817e-18]),
#      'pair_distance': 5.432005264118769,
#      'included': False},
#     {'id': 6,
#      'number': 2,
#      'direction': [1, 1, 0],
#      'displacement': array([2.12132034e-02, 2.12132034e-02, 2.59786817e-18]),
#      'pair_distance': 5.432005264118769,
#      'included': False},
#     {'id': 7,
#      'number': 2,
#      'direction': [-1, -1, 0],
#      'displacement': array([-2.12132034e-02, -2.12132034e-02, -2.59786817e-18]),
#      'pair_distance': 5.432005264118769,
#      'included': False},
#     {'id': 8,
#      'number': 2,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 5.432005264118769,
#      'included': False},
#     {'id': 9,
#      'number': 3,
#      'direction': [1, 1, 0],
#      'displacement': array([2.12132034e-02, 2.12132034e-02, 2.59786817e-18]),
#      'pair_distance': 7.682015515398809,
#      'included': False},
#     {'id': 10,
#      'number': 3,
#      'direction': [-1, -1, 0],
#      'displacement': array([-2.12132034e-02, -2.12132034e-02, -2.59786817e-18]),
#      'pair_distance': 7.682015515398809,
#      'included': False},
#     {'id': 11,
#      'number': 3,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 7.682015515398809,
#      'included': False},
#     {'id': 12,
#      'number': 6,
#      'direction': [1, 1, 0],
#      'displacement': array([2.12132034e-02, 2.12132034e-02, 2.59786817e-18]),
#      'pair_distance': 7.682015515398809,
#      'included': False},
#     {'id': 13,
#      'number': 6,
#      'direction': [-1, -1, 0],
#      'displacement': array([-2.12132034e-02, -2.12132034e-02, -2.59786817e-18]),
#      'pair_distance': 7.682015515398809,
#      'included': False},
#     {'id': 14,
#      'number': 7,
#      'direction': [1, 1, 0],
#      'displacement': array([2.12132034e-02, 2.12132034e-02, 2.59786817e-18]),
#      'pair_distance': 9.408509104435307,
#      'included': False},
#     {'id': 15,
#      'number': 7,
#      'direction': [-1, -1, 0],
#      'displacement': array([-2.12132034e-02, -2.12132034e-02, -2.59786817e-18]),
#      'pair_distance': 9.408509104435307,
#      'included': False},
#     {'id': 16,
#      'number': 8,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 17,
#      'number': 8,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 18,
#      'number': 8,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 19,
#      'number': 8,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 20,
#      'number': 9,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 21,
#      'number': 9,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 22,
#      'number': 9,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 23,
#      'number': 9,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 24,
#      'number': 10,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 25,
#      'number': 10,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 26,
#      'number': 10,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 27,
#      'number': 10,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 28,
#      'number': 11,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 29,
#      'number': 11,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 30,
#      'number': 11,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 31,
#      'number': 11,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 32,
#      'number': 16,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 33,
#      'number': 16,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 34,
#      'number': 16,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 35,
#      'number': 16,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 36,
#      'number': 16,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 37,
#      'number': 16,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 3.841007757699404,
#      'included': False},
#     {'id': 38,
#      'number': 17,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 39,
#      'number': 17,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 40,
#      'number': 17,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 41,
#      'number': 17,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 42,
#      'number': 17,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 43,
#      'number': 17,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 3.8410077576994035,
#      'included': False},
#     {'id': 44,
#      'number': 18,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 45,
#      'number': 18,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 46,
#      'number': 18,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 47,
#      'number': 18,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 48,
#      'number': 18,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 49,
#      'number': 18,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 6.652820588601576,
#      'included': False},
#     {'id': 50,
#      'number': 19,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 6.652820588601575,
#      'included': False},
#     {'id': 51,
#      'number': 19,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 6.652820588601575,
#      'included': False},
#     {'id': 52,
#      'number': 19,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 6.652820588601575,
#      'included': False},
#     {'id': 53,
#      'number': 19,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 6.652820588601575,
#      'included': False},
#     {'id': 54,
#      'number': 19,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 6.652820588601575,
#      'included': False},
#     {'id': 55,
#      'number': 19,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 6.652820588601575,
#      'included': False},
#     {'id': 56,
#      'number': 32,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 7.0563818283264785,
#      'included': False},
#     {'id': 57,
#      'number': 32,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 7.0563818283264785,
#      'included': False},
#     {'id': 58,
#      'number': 32,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 7.0563818283264785,
#      'included': False},
#     {'id': 59,
#      'number': 32,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 7.0563818283264785,
#      'included': False},
#     {'id': 60,
#      'number': 33,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 61,
#      'number': 33,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 62,
#      'number': 33,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 63,
#      'number': 33,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 64,
#      'number': 34,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 65,
#      'number': 34,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 66,
#      'number': 34,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 67,
#      'number': 34,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 68,
#      'number': 34,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 69,
#      'number': 34,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 5.919390501768668,
#      'included': False},
#     {'id': 70,
#      'number': 35,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 71,
#      'number': 35,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 72,
#      'number': 35,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 73,
#      'number': 35,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 74,
#      'number': 35,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 75,
#      'number': 35,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 76,
#      'number': 38,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 4.5039808300793345,
#      'included': False},
#     {'id': 77,
#      'number': 38,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 4.5039808300793345,
#      'included': False},
#     {'id': 78,
#      'number': 38,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 4.5039808300793345,
#      'included': False},
#     {'id': 79,
#      'number': 38,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 4.5039808300793345,
#      'included': False},
#     {'id': 80,
#      'number': 39,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 2.352127276108827,
#      'included': True},
#     {'id': 81,
#      'number': 39,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 2.352127276108827,
#      'included': True},
#     {'id': 82,
#      'number': 39,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 2.352127276108827,
#      'included': True},
#     {'id': 83,
#      'number': 39,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 2.352127276108827,
#      'included': True},
#     {'id': 84,
#      'number': 48,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 85,
#      'number': 48,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 86,
#      'number': 48,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 87,
#      'number': 48,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 88,
#      'number': 48,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 89,
#      'number': 48,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 4.503980830079334,
#      'included': False},
#     {'id': 90,
#      'number': 49,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 5.919390501768669,
#      'included': False},
#     {'id': 91,
#      'number': 49,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 5.919390501768669,
#      'included': False},
#     {'id': 92,
#      'number': 49,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 5.919390501768669,
#      'included': False},
#     {'id': 93,
#      'number': 49,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 5.919390501768669,
#      'included': False},
#     {'id': 94,
#      'number': 49,
#      'direction': [0, 0, 1],
#      'displacement': array([0.  , 0.  , 0.03]),
#      'pair_distance': 5.919390501768669,
#      'included': False},
#     {'id': 95,
#      'number': 49,
#      'direction': [0, 0, -1],
#      'displacement': array([ 0.  ,  0.  , -0.03]),
#      'pair_distance': 5.919390501768669,
#      'included': False},
#     {'id': 96,
#      'number': 50,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 2.3521272761088254,
#      'included': True},
#     {'id': 97,
#      'number': 50,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 2.3521272761088254,
#      'included': True},
#     {'id': 98,
#      'number': 50,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 2.3521272761088254,
#      'included': True},
#     {'id': 99,
#      'number': 50,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 2.3521272761088254,
#      'included': True},
#     {'id': 100,
#      'number': 51,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 4.503980830079335,
#      'included': False},
#     {'id': 101,
#      'number': 51,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 4.503980830079335,
#      'included': False},
#     {'id': 102,
#      'number': 51,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 4.503980830079335,
#      'included': False},
#     {'id': 103,
#      'number': 51,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 4.503980830079335,
#      'included': False},
#     {'id': 104,
#      'number': 52,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 5.91939050176867,
#      'included': False},
#     {'id': 105,
#      'number': 52,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 5.91939050176867,
#      'included': False},
#     {'id': 106,
#      'number': 52,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 5.91939050176867,
#      'included': False},
#     {'id': 107,
#      'number': 52,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 5.91939050176867,
#      'included': False},
#     {'id': 108,
#      'number': 53,
#      'direction': [0, 1, 0],
#      'displacement': array([0.0000000e+00, 3.0000000e-02, 1.8369702e-18]),
#      'pair_distance': 7.05638182832648,
#      'included': False},
#     {'id': 109,
#      'number': 53,
#      'direction': [0, -1, 0],
#      'displacement': array([ 0.0000000e+00, -3.0000000e-02, -1.8369702e-18]),
#      'pair_distance': 7.05638182832648,
#      'included': False},
#     {'id': 110,
#      'number': 53,
#      'direction': [1, 0, 0],
#      'displacement': array([3.0000000e-02, 1.8369702e-18, 1.8369702e-18]),
#      'pair_distance': 7.05638182832648,
#      'included': False},
#     {'id': 111,
#      'number': 53,
#      'direction': [-1, 0, 0],
#      'displacement': array([-3.0000000e-02, -1.8369702e-18, -1.8369702e-18]),
#      'pair_distance': 7.05638182832648,
#      'included': False}]}]}

# %%
phono.phonon_dataset
# Out:
# {'natom': 512,
#  'first_atoms': [{'number': 0,
#    'displacement': [0.03, 1.8369701987210304e-18, 1.8369701987210304e-18]}]}

# %%
phono.supercells_with_displacements
# Out:
# [<phonopy.structure.atoms.PhonopyAtoms at 0x7f927a7075d0>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f927a707710>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f927a707910>,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f927a707f90>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f927a78b610>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f927a78b5d0>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f9293dad0d0>,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f9282f28bd0>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f9282f28150>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f91a415b190>,
#  <phonopy.structure.atoms.PhonopyAtoms at 0x7f91a415b0d0>,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
phono.phonon_supercells_with_displacements

# %%
len(phono.supercells_with_displacements)
# Out:
# 111

# %%
len(phono.phonon_supercells_with_displacements)
# Out:
# 1

# %%
structure_lst = [phonopy_to_atoms(s) for s in phono.supercells_with_displacements if s is not None]

# %%
structure_phono_lst = [phonopy_to_atoms(s) for s in phono.phonon_supercells_with_displacements]

# %%
forces_lst = []
for i, s in enumerate(structure_lst):
    job_displace = pr.create.job.Lammps("job_" + str(i))
    job_displace.structure = s
    job_displace.potential = '1994--Tersoff-J--Si-C--LAMMPS--ipr1'
    job_displace.run()
    forces_lst.append(job_displace["output/generic/forces"][-1])
# Out:
# The job job_0 was saved and received the ID: 2
# The job job_1 was saved and received the ID: 3
# The job job_2 was saved and received the ID: 4
# The job job_3 was saved and received the ID: 5
# The job job_4 was saved and received the ID: 6
# The job job_5 was saved and received the ID: 7
# The job job_6 was saved and received the ID: 8
# The job job_7 was saved and received the ID: 9
# The job job_8 was saved and received the ID: 10
# The job job_9 was saved and received the ID: 11
# The job job_10 was saved and received the ID: 12

# %%
forces_phono_lst = []
for i, s in enumerate(structure_phono_lst):
    job_displace = pr.create.job.Lammps("job_phono_" + str(i))
    job_displace.structure = s
    job_displace.potential = '1994--Tersoff-J--Si-C--LAMMPS--ipr1'
    job_displace.run()
    forces_phono_lst.append(job_displace["output/generic/forces"][-1])
# Out:
# The job job_phono_0 was saved and received the ID: 13

# %%
np.array(forces_lst).shape
# Out:
# (11, 64, 3)

# %%
forces_new_lst = []
i = 0
for displace in phono.supercells_with_displacements:
    if displace is not None:
        forces_new_lst.append(forces_lst[i])
        i += 1
    else:
        forces_new_lst.append(np.zeros([64, 3]))

# %%
phono.forces = np.array(forces_new_lst)

# %%
phono.phonon_forces = np.array(forces_phono_lst)

# %%
phono.produce_fc2()

# %%
phono.produce_fc3()

# %%
phono.init_phph_interaction()

# %%
phono.run_phonon_solver()

# %%
phono.run_thermal_conductivity()

# %%
phono.thermal_conductivity.kappa
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 1.23779199e+04,  1.23779199e+04,  1.23779199e+04,
#          -2.02302227e-13, -3.23303698e-14, -1.19921048e-12],
#         [ 7.60636644e+03,  7.60636644e+03,  7.60636644e+03,
#           1.13295212e-14, -5.80617536e-15, -7.22693729e-13],
#         [ 6.77715906e+03,  6.77715906e+03,  6.77715906e+03,
#           5.58534735e-14, -4.98326675e-15, -6.38065976e-13],
#         [ 5.41401080e+03,  5.41401080e+03,  5.41401080e+03,
#           5.68516576e-14,  1.31258770e-15, -5.08619671e-13],
#         [ 4.18741502e+03,  4.18741502e+03,  4.18741502e+03,
#           4.75044971e-14,  5.71172085e-15, -3.92962595e-13],
#         [ 3.24755334e+03,  3.24755334e+03,  3.24755334e+03,
#           3.75294243e-14,  7.02920529e-15, -3.04479302e-13],
#         [ 2.54585571e+03,  2.54585571e+03,  2.54585571e+03,
#           2.92625793e-14,  6.75280969e-15, -2.38429362e-13],
#         [ 2.02448892e+03,  2.02448892e+03,  2.02448892e+03,
#           2.29538760e-14,  5.96091438e-15, -1.89343706e-13],
#         [ 1.63754502e+03,  1.63754502e+03,  1.63754502e+03,
